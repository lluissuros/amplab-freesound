# %% [markdown]
# # 1) Create source sound collection
#
# This notebook includes the code to create the collection of sounds that will later be used as source material for our audio mosaicing application. The collection of sounds is created by defining a number of queries to be performed using the Freesound API and concatenanting the results of each query. A number of metadata fields are stored for each sound in the collection and saved into a Pandas DataFrame object and CSV file in disk. For each sound in the collection, we also download an OGG preview and store it in disk.
#
# This notebook uses the `freesound` Python package for interacting with the Freesound API. The source code for this package can be found here: https://github.com/mtg/freesound-python. In this repository you'll find a Python script with [examples](https://github.com/MTG/freesound-python/blob/master/examples.py) to learn how to interact with the API. Nevertheless, if you are further interested in the Freesound API, check the [API documentation](http://freesound.org/docs/api/) which provides more information.
#
# **NOTE**: A Freesound API key is provided in this notebook, but you should make a Freesound account and get your own key. You can get a key here: https://freesound.org/apiv2/apply/

# %%
import os
import pandas as pd
import numpy as np
import freesound
from IPython.display import display

FREESOUND_API_KEY = 's9xV21k899aPetFLLLj7IQjq2hCprXG0IqymUEy1'  # my api key
FILES_DIR = 'files'  # Place where to store the downloaded diles. Will be relative to the current folder.
DATAFRAME_FILENAME = 'dataframe.csv'  # File where we'll store the metadata of our sounds collection
FREESOUND_STORE_METADATA_FIELDS = ['id', 'name', 'username', 'previews', 'license', 'tags']  # Freesound metadata properties to store

freesound_client = freesound.FreesoundClient()
freesound_client.set_token(FREESOUND_API_KEY)
if not os.path.exists(FILES_DIR): os.mkdir(FILES_DIR)

# %%
# Define some util functions

def query_freesound(query, filter, num_results=10):
    """Queries freesound with the given query and filter values.
    If no filter is given, a default filter is added to only get sounds shorter than 30 seconds.
    """
    if filter is None:
        filter = 'duration:[0 TO 30]'  # Set default filter
    pager = freesound_client.text_search(
        query = query,
        filter = filter,
        fields = ','.join(FREESOUND_STORE_METADATA_FIELDS),
        group_by_pack = 1,
        page_size = num_results
    )
    return [sound for sound in pager]

def retrieve_sound_preview(sound, directory):
    """Download the high-quality OGG sound preview of a given Freesound sound object to the given directory.
    """
    return freesound.FSRequest.retrieve(
        sound.previews.preview_hq_ogg,
        freesound_client,
        os.path.join(directory, sound.previews.preview_hq_ogg.split('/')[-1])
    )

def make_pandas_record(sound, file_path = "files/"): 
    """Create a dictionary with the metadata that we want to store for each sound.
    """
    record = {key: sound.as_dict()[key] for key in FREESOUND_STORE_METADATA_FIELDS}
    del record['previews']  # Don't store previews dict in record
    record['freesound_id'] = record['id']  # Rename 'id' to 'freesound_id'
    del record['id']
    record['path'] = file_path + sound.previews.preview_hq_ogg.split("/")[-1]  # Store path of downloaded file
    return record

# %%
# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
freesound_queries = [
    {
        'query': 'dog bark',
        'filter': None,
        'num_results': 20, 
    },
    {
        'query': 'percussion sounds',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
    {
        'query': 'vocals',
        'filter': 'duration:[0 TO 1]',
        'num_results': 20, 
    },
]

# Do all queries and concatenate the results in a single list of sounds
sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

# Download the sounds and save them to FILES_DIR folder
for count, sound in enumerate(sounds):
    print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
    retrieve_sound_preview(sound, 'files/')
    
# Make a Pandas DataFrame with the metadata of our sound collection and save it
df =  pd.DataFrame([make_pandas_record(s) for s in sounds])
df.to_csv(DATAFRAME_FILENAME)
print('Saved DataFrame with {0} entries! {1}'.format(len(df), DATAFRAME_FILENAME))

# Show the contents of our DataFrame (the metadata of our source collection)
display(df)
# Out:
# Downloading sound with id 337101 [1/60]
# Downloading sound with id 327666 [2/60]
# Downloading sound with id 413758 [3/60]
# Downloading sound with id 163459 [4/60]
# Downloading sound with id 456943 [5/60]
# Downloading sound with id 418105 [6/60]
# Downloading sound with id 420447 [7/60]
# Downloading sound with id 236011 [8/60]
# Downloading sound with id 115536 [9/60]
# Downloading sound with id 160092 [10/60]
# Downloading sound with id 180977 [11/60]
# Downloading sound with id 157322 [12/60]
# Downloading sound with id 425904 [13/60]
# Downloading sound with id 118961 [14/60]
# Downloading sound with id 386766 [15/60]
# Downloading sound with id 199261 [16/60]
# Downloading sound with id 277058 [17/60]
# Downloading sound with id 446593 [18/60]
# Downloading sound with id 408810 [19/60]
# Downloading sound with id 424593 [20/60]
# Downloading sound with id 124100 [21/60]
# Downloading sound with id 57040 [22/60]
# Downloading sound with id 260468 [23/60]
# Downloading sound with id 183115 [24/60]
# Downloading sound with id 338747 [25/60]
# Downloading sound with id 424372 [26/60]
# Downloading sound with id 264173 [27/60]
# Downloading sound with id 31061 [28/60]
# Downloading sound with id 207913 [29/60]
# Downloading sound with id 249971 [30/60]
# Downloading sound with id 193977 [31/60]
# Downloading sound with id 139500 [32/60]
# Downloading sound with id 111163 [33/60]
# Downloading sound with id 65688 [34/60]
# Downloading sound with id 329924 [35/60]
# Downloading sound with id 345679 [36/60]
# Downloading sound with id 63240 [37/60]
# Downloading sound with id 396226 [38/60]
# Downloading sound with id 399329 [39/60]
# Downloading sound with id 347121 [40/60]
# Downloading sound with id 315688 [41/60]
# Downloading sound with id 75509 [42/60]
# Downloading sound with id 33753 [43/60]
# Downloading sound with id 432875 [44/60]
# Downloading sound with id 272029 [45/60]
# Downloading sound with id 87649 [46/60]
# Downloading sound with id 88159 [47/60]
# Downloading sound with id 251683 [48/60]
# Downloading sound with id 417506 [49/60]
# Downloading sound with id 88402 [50/60]
# Downloading sound with id 150505 [51/60]
# Downloading sound with id 166161 [52/60]
# Downloading sound with id 180343 [53/60]
# Downloading sound with id 166357 [54/60]
# Downloading sound with id 215363 [55/60]
# Downloading sound with id 112582 [56/60]
# Downloading sound with id 87697 [57/60]
# Downloading sound with id 181881 [58/60]
# Downloading sound with id 256359 [59/60]
# Downloading sound with id 254275 [60/60]
# Saved DataFrame with 60 entries! dataframe.csv
#     freesound_id                                            license  \
# 0         337101  http://creativecommons.org/publicdomain/zero/1.0/
# 1         327666     http://creativecommons.org/licenses/by-nc/3.0/
# 2         413758  http://creativecommons.org/publicdomain/zero/1.0/
# 3         163459  http://creativecommons.org/publicdomain/zero/1.0/
# 4         456943  http://creativecommons.org/publicdomain/zero/1.0/
# 5         418105        http://creativecommons.org/licenses/by/3.0/
# 6         420447  http://creativecommons.org/publicdomain/zero/1.0/
# 7         236011     http://creativecommons.org/licenses/by-nc/3.0/
# 8         115536        http://creativecommons.org/licenses/by/3.0/
# 9         160092        http://creativecommons.org/licenses/by/3.0/
# 10        180977  http://creativecommons.org/publicdomain/zero/1.0/
# 11        157322        http://creativecommons.org/licenses/by/3.0/
# 12        425904  http://creativecommons.org/publicdomain/zero/1.0/
# 13        118961  http://creativecommons.org/publicdomain/zero/1.0/
# 14        386766  http://creativecommons.org/publicdomain/zero/1.0/
# 15        199261  http://creativecommons.org/publicdomain/zero/1.0/
# 16        277058  http://creativecommons.org/publicdomain/zero/1.0/
# 17        446593  http://creativecommons.org/publicdomain/zero/1.0/
# 18        408810     http://creativecommons.org/licenses/by-nc/3.0/
# 19        424593  http://creativecommons.org/publicdomain/zero/1.0/
# 20        124100  http://creativecommons.org/publicdomain/zero/1.0/
# 21         57040        http://creativecommons.org/licenses/by/3.0/
# 22        260468  http://creativecommons.org/publicdomain/zero/1.0/
# 23        183115        http://creativecommons.org/licenses/by/3.0/
# 24        338747  http://creativecommons.org/publicdomain/zero/1.0/
# 25        424372  http://creativecommons.org/publicdomain/zero/1.0/
# 26        264173        http://creativecommons.org/licenses/by/3.0/
# 27         31061     http://creativecommons.org/licenses/by-nc/3.0/
# 28        207913        http://creativecommons.org/licenses/by/3.0/
# 29        249971        http://creativecommons.org/licenses/by/3.0/
# 30        193977  http://creativecommons.org/publicdomain/zero/1.0/
# 31        139500  http://creativecommons.org/publicdomain/zero/1.0/
# 32        111163        http://creativecommons.org/licenses/by/3.0/
# 33         65688        http://creativecommons.org/licenses/by/3.0/
# 34        329924        http://creativecommons.org/licenses/by/3.0/
# 35        345679        http://creativecommons.org/licenses/by/3.0/
# 36         63240     http://creativecommons.org/licenses/by-nc/3.0/
# 37        396226  http://creativecommons.org/publicdomain/zero/1.0/
# 38        399329  http://creativecommons.org/publicdomain/zero/1.0/
# 39        347121  http://creativecommons.org/publicdomain/zero/1.0/
# 40        315688  http://creativecommons.org/publicdomain/zero/1.0/
# 41         75509  http://creativecommons.org/publicdomain/zero/1.0/
# 42         33753  http://creativecommons.org/publicdomain/zero/1.0/
# 43        432875        http://creativecommons.org/licenses/by/3.0/
# 44        272029  http://creativecommons.org/publicdomain/zero/1.0/
# 45         87649  http://creativecommons.org/publicdomain/zero/1.0/
# 46         88159  http://creativecommons.org/licenses/sampling+/...
# 47        251683  http://creativecommons.org/publicdomain/zero/1.0/
# 48        417506        http://creativecommons.org/licenses/by/3.0/
# 49         88402  http://creativecommons.org/publicdomain/zero/1.0/
# 50        150505  http://creativecommons.org/publicdomain/zero/1.0/
# 51        166161  http://creativecommons.org/publicdomain/zero/1.0/
# 52        180343        http://creativecommons.org/licenses/by/3.0/
# 53        166357        http://creativecommons.org/licenses/by/3.0/
# 54        215363  http://creativecommons.org/publicdomain/zero/1.0/
# 55        112582     http://creativecommons.org/licenses/by-nc/3.0/
# 56         87697  http://creativecommons.org/licenses/sampling+/...
# 57        181881        http://creativecommons.org/licenses/by/3.0/
# 58        256359        http://creativecommons.org/licenses/by/3.0/
# 59        254275     http://creativecommons.org/licenses/by-nc/3.0/
#
#                                                  name  \
# 0                           Group_of_Dogs_Barking.WAV
# 1                                        Dog Bark.wav
# 2                                      dogbarking.mp3
# 3                  LBS_FX DOG Small Alert Bark001.wav
# 4                         Blossom Bark  29sec mix.wav
# 5                                   single dog bark 3
# 6                                       Barking 4.wav
# 7                  Jazz the Dog Howl & Bark (136).wav
# 8                                       Two Barks.wav
# 9                                          Dog bark 1
# 10                                        Barking Dog
# 11                 Dog Bark Staffordshire Bullterrier
# 12                                         BarkingDog
# 13                                     Dog Bark 1.wav
# 14                                    Dog_Barking.wav
# 15                    A dog barking (close recording)
# 16                                    Single Dog Bark
# 17                                        Barking Dog
# 18                                       Dog Bark.wav
# 19                                    Dog Barking.m4a
# 20                                       Ch Sound.wav
# 21                                 suctioncupkick.wav
# 22                 electribe-kicks slice 0A [A#4].wav
# 23                                   prc_appet909.wav
# 24           Perc. coffee tin 04 muted March 2016.wav
# 25                             percussion sound 2.wav
# 26                                 original sound.wav
# 27                                       Sound 13.wav
# 28                                      Bandpass snap
# 29                                  Short_sound_3.wav
# 30                                   Knife Hit 25.wav
# 31                                         various 28
# 32                               firecracker_coke.wav
# 33                                     toiletseat.wav
# 34                               Knocking on Door.wav
# 35                                       wood hit.wav
# 36  ac004 tambourine one hand shot with pre sound.wav
# 37       click/hi hat sound (sample off of Flume).wav
# 38   plastic - bubble wrap - shaker type sound 01.wav
# 39                    HeavyHot Snare - Nova Sound.wav
# 40                                             ououou
# 41                                           base.mp3
# 42                                           FUGg.wav
# 43                                       LFS_Vox8.wav
# 44                                         Male cough
# 45                                              e.wav
# 46                                        vocal A.wav
# 47                                            Nah.wav
# 48                                        jucuzzi.wav
# 49                                     aaaaa_GNAS.wav
# 50                                       Huh? - Vocal
# 51                                   Vocal_male_1.wav
# 52                              Short scared scream 1
# 53               "Alarm" (Male Voice through Speaker)
# 54                                           bee2.wav
# 55                                              a.wav
# 56                                              a.wav
# 57                                         Ay Vox cut
# 58                      Robotic Vocal saying - Groovy
# 59                                   Airy vocal cough
#
#                            path  \
# 0   files/337101_3474310-hq.ogg
# 1   files/327666_5632380-hq.ogg
# 2   files/413758_7958399-hq.ogg
# 3   files/163459_2965892-hq.ogg
# 4   files/456943_3194431-hq.ogg
# 5   files/418105_6078577-hq.ogg
# 6   files/420447_2402876-hq.ogg
# 7    files/236011_180659-hq.ogg
# 8   files/115536_1956076-hq.ogg
# 9   files/160092_2888453-hq.ogg
# 10  files/180977_3370987-hq.ogg
# 11       files/157322_58-hq.ogg
# 12  files/425904_8563244-hq.ogg
# 13  files/118961_1990695-hq.ogg
# 14  files/386766_5768130-hq.ogg
# 15  files/199261_1661766-hq.ogg
# 16  files/277058_4486188-hq.ogg
# 17  files/446593_9134393-hq.ogg
# 18  files/408810_7208336-hq.ogg
# 19  files/424593_8518940-hq.ogg
# 20  files/124100_2219481-hq.ogg
# 21      files/57040_4948-hq.ogg
# 22  files/260468_2127539-hq.ogg
# 23  files/183115_2394245-hq.ogg
# 24  files/338747_5450487-hq.ogg
# 25  files/424372_7099958-hq.ogg
# 26  files/264173_2750665-hq.ogg
# 27     files/31061_33110-hq.ogg
# 28    files/207913_19852-hq.ogg
# 29    files/249971_97763-hq.ogg
# 30  files/193977_3022224-hq.ogg
# 31  files/139500_1951924-hq.ogg
# 32     files/111163_4948-hq.ogg
# 33      files/65688_4948-hq.ogg
# 34  files/329924_2812020-hq.ogg
# 35  files/345679_2775767-hq.ogg
# 36    files/63240_321967-hq.ogg
# 37  files/396226_3202651-hq.ogg
# 38  files/399329_5923045-hq.ogg
# 39   files/347121_369949-hq.ogg
# 40  files/315688_3442171-hq.ogg
# 41    files/75509_818377-hq.ogg
# 42    files/33753_213746-hq.ogg
# 43  files/432875_4157918-hq.ogg
# 44  files/272029_5165013-hq.ogg
# 45    files/87649_664547-hq.ogg
# 46   files/88159_1269037-hq.ogg
# 47  files/251683_1730960-hq.ogg
# 48  files/417506_1453392-hq.ogg
# 49   files/88402_1097185-hq.ogg
# 50  files/150505_1883289-hq.ogg
# 51  files/166161_2104797-hq.ogg
# 52  files/180343_2888453-hq.ogg
# 53    files/166357_71257-hq.ogg
# 54   files/215363_950925-hq.ogg
# 55  files/112582_1813144-hq.ogg
# 56   files/87697_1265297-hq.ogg
# 57  files/181881_3172867-hq.ogg
# 58  files/256359_4062622-hq.ogg
# 59  files/254275_4062622-hq.ogg
#
#                                                  tags           username
# 0   [growling, growl, Group, barking, animal, pet,...            ivolipa
# 1   [bellow, barking, intimidating, angrily, bark,...  Juan_Merie_Venter
# 2                      [barking, Dog, dog, bark, big]      lala_davis554
# 3              [Chihuahua, FX, Dog, dog, Small, bark]    LittleBigSounds
# 4    [howl, bark, dog, Dog, barking, German-shepherd]            Zajjman
# 5   [bark, animal, dog, pet, barking, growl, growl...        crazymonke9
# 6   [pets, howl, wolves, wolf, dog, animals, snarl...       Mrthenoronha
# 7   [Barking, Jazz, Barks, Dog, Howling, Wolf, Ani...      delphidebrain
# 8   [animal, bark, barking, dog, effects, noise, s...             Puniho
# 9                           [average-size, bark, Dog]        jorickhoofd
# 10                  [bark, happy, loud, dog, barking]        Suprasummun
# 11  [sennheiser, sound-devices, dog, m-s, stafford...              Anton
# 12                      [dog, bark, InterSpecies2018]         NatalieTre
# 13                                [animal, bark, dog]            esperri
# 14                               [barking, dog, bark]             ken788
# 15  [moan, blume, barking, usa, grunting, felix, d...        felix.blume
# 16  [animal, pet, dog, public-domain, woof, single...         kwahmah_02
# 17                                [Animal, Dog, Bark]        Nicolas4677
# 18  [bark, animal, dog, dog-barking, pet, barking,...             Okuhle
# 19                               [Barking, Dog, Bark]     Daniela-Santos
# 20  [beatboxing, connersaw8, mouth, percussion, so...         connersaw8
# 21    [dangerous, foley, kitchen, percussion, sounds]     NoiseCollector
# 22  [bd, groovebox, presets, drum, bassdrum, percu...        soneproject
# 23  [perc, hits, drums, house, Percussion, music, ...               DWSD
# 24  [sample-pack, sampling, sample, raw, Sampler, ...        cabled_mess
# 25                     [percussive, percussion, perc]            Elnosos
# 26  [perc, one-shot, hit, sfx, percussion, snaree,...        GabrieleKkj
# 27  [box, bridge, drum, industrial, metal, percuss...          scuzzpuck
# 28          [percussion, imposcar, softsynth, gforce]           altemark
# 29  [noise, AM, Twente-University, short-wave, per...           AlienXXX
# 30  [drum, metal, silverware, metallic, percussion...        potentjello
# 31                          [snap, percussion, click]           arseniiv
# 32                     [firecracker, hit, percussion]     NoiseCollector
# 33                         [percussion, seat, toilet]     NoiseCollector
# 34  [hit, knock, door, wooden, rythmic, knocking, ...            Uzbazur
# 35  [impact, industrial, hit, high-quality, metal,...           VitaWrap
# 36        [drums, percussion, percussive, tambourine]        Robinhood76
# 37  [click, hi-hat, drums, percussion, high-hat, b...           lavaande
# 38  [packing-material, packing, percussion, bubble...          Anthousai
# 39  [Flames, Burning, Fire, Fireworks, Percussion,...             Fiditg
# 40  [one-shot-sample, spoken-word, vocal-sample, v...          Roses1401
# 41  [acapella, acapellas, akapella, base, bass, ha...              TiBRo
# 42  [bcjordan, fuck, jerk, speech, vocal, vocals, ...           bcjordan
# 43  [scream, male, vocals, stupid, vocal, voice, s...            xtrgamr
# 44  [cough, vocal, voice, vocals, human, sounds, m...         aldenroth2
# 45                        [catalan, e, vocals, voice]            vallver
# 46                                         [a, vocal]             tajada
# 47  [henriquedesa, voice, vocalizations, vocal, hu...       henriquedesa
# 48                             [human, voice, sample]         Xcreenplay
# 49      [68880, a, digital, parla, tractament, vocal]     guillemnicolau
# 50     [boy, vocale, huh, confused, vocal, guy, male]          davdud101
# 51                           [voice, male, eh, vocal]             Adam_N
# 52  [anxious, male, fearful, scared, alarmed, afra...        jorickhoofd
# 53  [male, alarm, accent, robot, echo, warning, sp...            qubodup
# 54                                 [voice, buzz, bee]           Reitanna
# 55                                       [a, spanish]             kosden
# 56                                                [a]           ruben226
# 57        [FX, effect, Vocal, JLee, Vox, 4x4-records]             Goup_1
# 58  [droid, dance, Countdown, Synthesizer, Speech,...          Jagadamba
# 59              [voice, airy, coughing, cough, vocal]          Jagadamba

# %%
#MY OWN CONTRIBUTION

# Build our collection of sounds

# Our collection of sounds is made by appending the results of a number of different queries to freesound
# The query terms, query filters and the number of results per query are all defined here.
# Information about how to define filters can be found in the Freesound API documentation: https://freesound.org/docs/api/resources_apiv2.html#request-parameters-text-search-parameters
sounds_to_save_path_harmony = 'deliverables/harmony/'
sounds_to_save_path_drums = 'deliverables/drums/'

DATAFRAME_FILENAME_HARMONY = 'deliverables/dataframes/dataframe_harmony.csv'
DATAFRAME_FILENAME_DRUMS =  'deliverables/dataframes/dataframe_drums.csv'

# Build our collection of sounds
freesound_queries_harmony = [
    {
        'query': 'quartet',
        'filter': 'duration:[0 TO 30]',
        'num_results': 20, 
    },
    {
        'query': 'strings',
        'filter': 'duration:[0 TO 4]',
        'num_results': 30, 
    }
]


freesound_queries_drums = [
    {
        'query': 'drums',
        'filter': 'duration:[0 TO 2]',
        'num_results': 30, 
    },
    {
        'query': 'clapping',
        'filter': 'duration:[0 TO 2]',
        'num_results': 30, 
    }
]


def build_sound_collection(freesound_queries, sound_files_path, dataframe_filename):
    # Do all queries and concatenate the results in a single list of sounds
    sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

    # Download the sounds and save them to FILES_DIR folder
    for count, sound in enumerate(sounds):
        print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
        retrieve_sound_preview(sound, sound_files_path)

    # Make a Pandas DataFrame with the metadata of our sound collection and save it
    df =  pd.DataFrame([make_pandas_record(s, sound_files_path) for s in sounds])
    df.to_csv(dataframe_filename)
    print('Saved DataFrame with {0} entries! {1}'.format(len(df), dataframe_filename))

    # Show the contents of our DataFrame (the metadata of our source collection)
    display(df)
    return df



build_sound_collection(freesound_queries_harmony, sounds_to_save_path_harmony, DATAFRAME_FILENAME_HARMONY)
build_sound_collection(freesound_queries_drums, sounds_to_save_path_drums, DATAFRAME_FILENAME_DRUMS)
# Out:
# Downloading sound with id 44845 [1/41]
# Downloading sound with id 429954 [2/41]
# Downloading sound with id 361680 [3/41]
# Downloading sound with id 220449 [4/41]
# Downloading sound with id 438907 [5/41]
# Downloading sound with id 268603 [6/41]
# Downloading sound with id 31992 [7/41]
# Downloading sound with id 377029 [8/41]
# Downloading sound with id 220377 [9/41]
# Downloading sound with id 442291 [10/41]
# Downloading sound with id 412357 [11/41]
# Downloading sound with id 337895 [12/41]
# Downloading sound with id 342016 [13/41]
# Downloading sound with id 161167 [14/41]
# Downloading sound with id 121023 [15/41]
# Downloading sound with id 121031 [16/41]
# Downloading sound with id 257528 [17/41]
# Downloading sound with id 153644 [18/41]
# Downloading sound with id 134013 [19/41]
# Downloading sound with id 42710 [20/41]
# Downloading sound with id 395155 [21/41]
# Downloading sound with id 395156 [22/41]
# Downloading sound with id 395158 [23/41]
# Downloading sound with id 395159 [24/41]
# Downloading sound with id 395161 [25/41]
# Downloading sound with id 395162 [26/41]
# Downloading sound with id 395164 [27/41]
# Downloading sound with id 395165 [28/41]
# Downloading sound with id 395166 [29/41]
# Downloading sound with id 395167 [30/41]
# Downloading sound with id 395170 [31/41]
# Downloading sound with id 395173 [32/41]
# Downloading sound with id 395154 [33/41]
# Downloading sound with id 249195 [34/41]
# Downloading sound with id 151817 [35/41]
# Downloading sound with id 241337 [36/41]
# Downloading sound with id 190520 [37/41]
# Downloading sound with id 160243 [38/41]
# Downloading sound with id 167724 [39/41]
# Downloading sound with id 55306 [40/41]
# Downloading sound with id 372367 [41/41]
# Saved DataFrame with 41 entries! deliverables/dataframes/dataframe_harmony.csv
#     freesound_id                                            license  \
# 0          44845        http://creativecommons.org/licenses/by/3.0/
# 1         429954  http://creativecommons.org/publicdomain/zero/1.0/
# 2         361680        http://creativecommons.org/licenses/by/3.0/
# 3         220449  http://creativecommons.org/publicdomain/zero/1.0/
# 4         438907     http://creativecommons.org/licenses/by-nc/3.0/
# 5         268603        http://creativecommons.org/licenses/by/3.0/
# 6          31992        http://creativecommons.org/licenses/by/3.0/
# 7         377029        http://creativecommons.org/licenses/by/3.0/
# 8         220377  http://creativecommons.org/publicdomain/zero/1.0/
# 9         442291  http://creativecommons.org/publicdomain/zero/1.0/
# 10        412357        http://creativecommons.org/licenses/by/3.0/
# 11        337895     http://creativecommons.org/licenses/by-nc/3.0/
# 12        342016  http://creativecommons.org/publicdomain/zero/1.0/
# 13        161167        http://creativecommons.org/licenses/by/3.0/
# 14        121023        http://creativecommons.org/licenses/by/3.0/
# 15        121031        http://creativecommons.org/licenses/by/3.0/
# 16        257528        http://creativecommons.org/licenses/by/3.0/
# 17        153644     http://creativecommons.org/licenses/by-nc/3.0/
# 18        134013  http://creativecommons.org/publicdomain/zero/1.0/
# 19         42710        http://creativecommons.org/licenses/by/3.0/
# 20        395155     http://creativecommons.org/licenses/by-nc/3.0/
# 21        395156     http://creativecommons.org/licenses/by-nc/3.0/
# 22        395158     http://creativecommons.org/licenses/by-nc/3.0/
# 23        395159     http://creativecommons.org/licenses/by-nc/3.0/
# 24        395161     http://creativecommons.org/licenses/by-nc/3.0/
# 25        395162     http://creativecommons.org/licenses/by-nc/3.0/
# 26        395164     http://creativecommons.org/licenses/by-nc/3.0/
# 27        395165     http://creativecommons.org/licenses/by-nc/3.0/
# 28        395166     http://creativecommons.org/licenses/by-nc/3.0/
# 29        395167     http://creativecommons.org/licenses/by-nc/3.0/
# 30        395170     http://creativecommons.org/licenses/by-nc/3.0/
# 31        395173     http://creativecommons.org/licenses/by-nc/3.0/
# 32        395154     http://creativecommons.org/licenses/by-nc/3.0/
# 33        249195        http://creativecommons.org/licenses/by/3.0/
# 34        151817  http://creativecommons.org/publicdomain/zero/1.0/
# 35        241337     http://creativecommons.org/licenses/by-nc/3.0/
# 36        190520        http://creativecommons.org/licenses/by/3.0/
# 37        160243  http://creativecommons.org/publicdomain/zero/1.0/
# 38        167724  http://creativecommons.org/publicdomain/zero/1.0/
# 39         55306  http://creativecommons.org/publicdomain/zero/1.0/
# 40        372367        http://creativecommons.org/licenses/by/3.0/
#
#                                                  name  \
# 0                           string_quartet_stack1.aif
# 1                                             Strings
# 2              horncall_haydn31_hornsignal_Dmajor.wav
# 3                                      futurist03.wav
# 4                                      Tuning quartet
# 5                             ThereminQuartetLoop.wav
# 6                             Out of Tune Quartet.wav
# 7   090812 - Rijeka - Pavlinski Trg - Quartet Velj...
# 8                     Intonomuri_Documentation_02.wav
# 9                        string quartet tuning up.wav
# 10                                    horn lilt 1.wav
# 11                                      30Strings.wav
# 12                                      FM Strings A4
# 13                  Industrial_Strings_Loop_Noise.aif
# 14                               128 link strings.wav
# 15                         130 strings ensemble 2.wav
# 16                                       violin01.wav
# 17      Viola  Non-Vibrato Double Strings Pizzicato 1
# 18                                    Pick on strings
# 19                           01-synSTRINGS90s-¬SW.aif
# 20                            Live_LA Strings 009.wav
# 21                            Live_LA Strings 029.wav
# 22                            Live_LA Strings 023.wav
# 23                            Live_LA Strings 024.wav
# 24                            Live_LA Strings 022.wav
# 25                            Live_LA Strings 027.wav
# 26                            Live_LA Strings 025.wav
# 27                            Live_LA Strings 026.wav
# 28                            Live_LA Strings 014.wav
# 29                            Live_LA Strings 013.wav
# 30                            Live_LA Strings 018.wav
# 31                            Live_LA Strings 015.wav
# 32                            Live_LA Strings 010.wav
# 33                 swelling strings bpm 160 key c.wav
# 34                               String 002 Chord.wav
# 35                          Guitar String Slide Noise
# 36                              Strings trio hit2.wav
# 37                          4247 CFstgsPR2(A2)©SW.aif
# 38                               _stezzer_strings.wav
# 39                                    Old Strings.wav
# 40                            Tension Strings C Sharp
#
#                                           path  \
# 0      deliverables/harmony/44845_13258-hq.ogg
# 1   deliverables/harmony/429954_1691177-hq.ogg
# 2   deliverables/harmony/361680_6629901-hq.ogg
# 3   deliverables/harmony/220449_4070508-hq.ogg
# 4    deliverables/harmony/438907_520316-hq.ogg
# 5    deliverables/harmony/268603_688557-hq.ogg
# 6      deliverables/harmony/31992_54999-hq.ogg
# 7    deliverables/harmony/377029_695835-hq.ogg
# 8   deliverables/harmony/220377_4071748-hq.ogg
# 9     deliverables/harmony/442291_26563-hq.ogg
# 10  deliverables/harmony/412357_7717029-hq.ogg
# 11  deliverables/harmony/337895_5997821-hq.ogg
# 12  deliverables/harmony/342016_5622625-hq.ogg
# 13  deliverables/harmony/161167_2904837-hq.ogg
# 14  deliverables/harmony/121023_2193266-hq.ogg
# 15  deliverables/harmony/121031_2193266-hq.ogg
# 16     deliverables/harmony/257528_8043-hq.ogg
# 17  deliverables/harmony/153644_2626346-hq.ogg
# 18  deliverables/harmony/134013_1960341-hq.ogg
# 19    deliverables/harmony/42710_151878-hq.ogg
# 20  deliverables/harmony/395155_1603602-hq.ogg
# 21  deliverables/harmony/395156_1603602-hq.ogg
# 22  deliverables/harmony/395158_1603602-hq.ogg
# 23  deliverables/harmony/395159_1603602-hq.ogg
# 24  deliverables/harmony/395161_1603602-hq.ogg
# 25  deliverables/harmony/395162_1603602-hq.ogg
# 26  deliverables/harmony/395164_1603602-hq.ogg
# 27  deliverables/harmony/395165_1603602-hq.ogg
# 28  deliverables/harmony/395166_1603602-hq.ogg
# 29  deliverables/harmony/395167_1603602-hq.ogg
# 30  deliverables/harmony/395170_1603602-hq.ogg
# 31  deliverables/harmony/395173_1603602-hq.ogg
# 32  deliverables/harmony/395154_1603602-hq.ogg
# 33  deliverables/harmony/249195_3172867-hq.ogg
# 34    deliverables/harmony/151817_16058-hq.ogg
# 35   deliverables/harmony/241337_736471-hq.ogg
# 36  deliverables/harmony/190520_1414390-hq.ogg
# 37   deliverables/harmony/160243_151878-hq.ogg
# 38    deliverables/harmony/167724_33044-hq.ogg
# 39    deliverables/harmony/55306_164285-hq.ogg
# 40  deliverables/harmony/372367_5968459-hq.ogg
#
#                                                  tags           username
# 0   [atmosphere, cluster, dark, drone, fx, horror,...      thanvannispen
# 1                   [quartet, cello, Strings, violin]      MaxLandergard
# 2   [heroic, D-major, quartet, haydn, fanfare, hun...             TaranP
# 3                   [Russolo, futurist, Intonarumori]        KFerentchak
# 4   [tune, soundscape, piano, ambience, music, orc...  arnaud coutancier
# 5          [electronic, theremin, music, loop, synth]             moatdd
# 6      [finale, out-of-tune, string-quartet, strings]               Miuq
# 7   [hand-clapping, aplause, audience, ambience, a...            dkustic
# 8                    [intonomuri, woodwork, workshop]       AJFiorini317
# 9   [tune, strings, sound-effect, music, DAT, up, ...            electra
# 10      [horns, ambient, brass, orchestral, haunting]    ContextCollapse
# 11                               [simple, c, Strings]         fschaeffer
# 12                              [pad, strings, synth]           Terry93D
# 13      [dark-ambient, industrial, strings, metallic]    chr_garciabello
# 14  [cello, classical, orchestra, string, strings,...             Thirsk
# 15  [classical, orchestra, string, strings, violin...             Thirsk
# 16  [bowed, noise, percussion, fiddle, violin, str...           dobroide
# 17  [viola, chordophone, string-instrument, mezzof...     Carlos_Vaquero
# 18                  [guitar, strings, Electric, pick]         davidkyoku
# 19                  [d0, multisample, strings, synth]     Tom_McLaughlin
# 20                           [strings, Live, scoring]         gunnbladez
# 21                           [strings, Live, scoring]         gunnbladez
# 22                           [strings, Live, scoring]         gunnbladez
# 23                           [strings, Live, scoring]         gunnbladez
# 24                           [strings, Live, scoring]         gunnbladez
# 25                           [strings, Live, scoring]         gunnbladez
# 26                           [strings, Live, scoring]         gunnbladez
# 27                           [strings, Live, scoring]         gunnbladez
# 28                           [strings, Live, scoring]         gunnbladez
# 29                           [strings, Live, scoring]         gunnbladez
# 30                           [strings, Live, scoring]         gunnbladez
# 31                           [strings, Live, scoring]         gunnbladez
# 32                           [strings, Live, scoring]         gunnbladez
# 33  [Loop, Sample, Off-Shot-RECORDS, 4x4-Studios, ...             Goup_1
# 34  [one-shot, chord, string, stabs, DJX2, DJXII, ...          Karma-Ron
# 35  [noise, electric, MIDI, guitar, slide, GM, str...       Seidhepriest
# 36  [real, hit, field-recording, live, acoustic, s...           Slapbass
# 37          [Combfilter, Strings, Multisample, Synth]     Tom_McLaughlin
# 38  [gates, heaven, atmospheric, chords, spooky, p...        Snapper4298
# 39  [ambient, background, oldskool, orchestra, pad...          KatHakaku
# 40  [C-Sharp, Samples, Strings, Music-Based-on-Fin...        SSS_Samples
# Downloading sound with id 410514 [1/60]
# Downloading sound with id 190613 [2/60]
# Downloading sound with id 384668 [3/60]
# Downloading sound with id 459895 [4/60]
# Downloading sound with id 118524 [5/60]
# Downloading sound with id 318330 [6/60]
# Downloading sound with id 96016 [7/60]
# Downloading sound with id 264285 [8/60]
# Downloading sound with id 397016 [9/60]
# Downloading sound with id 324236 [10/60]
# Downloading sound with id 455633 [11/60]
# Downloading sound with id 323261 [12/60]
# Downloading sound with id 271078 [13/60]
# Downloading sound with id 269719 [14/60]
# Downloading sound with id 410149 [15/60]
# Downloading sound with id 137779 [16/60]
# Downloading sound with id 198100 [17/60]
# Downloading sound with id 156020 [18/60]
# Downloading sound with id 340467 [19/60]
# Downloading sound with id 194021 [20/60]
# Downloading sound with id 106144 [21/60]
# Downloading sound with id 116615 [22/60]
# Downloading sound with id 234425 [23/60]
# Downloading sound with id 445068 [24/60]
# Downloading sound with id 185615 [25/60]
# Downloading sound with id 41355 [26/60]
# Downloading sound with id 82247 [27/60]
# Downloading sound with id 414680 [28/60]
# Downloading sound with id 375287 [29/60]
# Downloading sound with id 100789 [30/60]
# Downloading sound with id 404539 [31/60]
# Downloading sound with id 436674 [32/60]
# Downloading sound with id 351993 [33/60]
# Downloading sound with id 321603 [34/60]
# Downloading sound with id 425909 [35/60]
# Downloading sound with id 63530 [36/60]
# Downloading sound with id 346580 [37/60]
# Downloading sound with id 169085 [38/60]
# Downloading sound with id 428377 [39/60]
# Downloading sound with id 25310 [40/60]
# Downloading sound with id 377779 [41/60]
# Downloading sound with id 418730 [42/60]
# Downloading sound with id 228362 [43/60]
# Downloading sound with id 388042 [44/60]
# Downloading sound with id 176434 [45/60]
# Downloading sound with id 432874 [46/60]
# Downloading sound with id 219605 [47/60]
# Downloading sound with id 98936 [48/60]
# Downloading sound with id 20717 [49/60]
# Downloading sound with id 241132 [50/60]
# Downloading sound with id 412157 [51/60]
# Downloading sound with id 434823 [52/60]
# Downloading sound with id 409614 [53/60]
# Downloading sound with id 449520 [54/60]
# Downloading sound with id 257769 [55/60]
# Downloading sound with id 99636 [56/60]
# Downloading sound with id 35035 [57/60]
# Downloading sound with id 391100 [58/60]
# Downloading sound with id 24786 [59/60]
# Downloading sound with id 207952 [60/60]
# Saved DataFrame with 60 entries! deliverables/dataframes/dataframe_drums.csv
#     freesound_id                                            license  \
# 0         410514        http://creativecommons.org/licenses/by/3.0/
# 1         190613        http://creativecommons.org/licenses/by/3.0/
# 2         384668  http://creativecommons.org/publicdomain/zero/1.0/
# 3         459895  http://creativecommons.org/publicdomain/zero/1.0/
# 4         118524  http://creativecommons.org/publicdomain/zero/1.0/
# 5         318330        http://creativecommons.org/licenses/by/3.0/
# 6          96016        http://creativecommons.org/licenses/by/3.0/
# 7         264285  http://creativecommons.org/publicdomain/zero/1.0/
# 8         397016        http://creativecommons.org/licenses/by/3.0/
# 9         324236        http://creativecommons.org/licenses/by/3.0/
# 10        455633  http://creativecommons.org/publicdomain/zero/1.0/
# 11        323261        http://creativecommons.org/licenses/by/3.0/
# 12        271078  http://creativecommons.org/publicdomain/zero/1.0/
# 13        269719  http://creativecommons.org/publicdomain/zero/1.0/
# 14        410149  http://creativecommons.org/publicdomain/zero/1.0/
# 15        137779        http://creativecommons.org/licenses/by/3.0/
# 16        198100        http://creativecommons.org/licenses/by/3.0/
# 17        156020        http://creativecommons.org/licenses/by/3.0/
# 18        340467  http://creativecommons.org/publicdomain/zero/1.0/
# 19        194021  http://creativecommons.org/publicdomain/zero/1.0/
# 20        106144        http://creativecommons.org/licenses/by/3.0/
# 21        116615        http://creativecommons.org/licenses/by/3.0/
# 22        234425        http://creativecommons.org/licenses/by/3.0/
# 23        445068  http://creativecommons.org/publicdomain/zero/1.0/
# 24        185615        http://creativecommons.org/licenses/by/3.0/
# 25         41355  http://creativecommons.org/publicdomain/zero/1.0/
# 26         82247  http://creativecommons.org/publicdomain/zero/1.0/
# 27        414680        http://creativecommons.org/licenses/by/3.0/
# 28        375287  http://creativecommons.org/publicdomain/zero/1.0/
# 29        100789        http://creativecommons.org/licenses/by/3.0/
# 30        404539        http://creativecommons.org/licenses/by/3.0/
# 31        436674  http://creativecommons.org/publicdomain/zero/1.0/
# 32        351993  http://creativecommons.org/publicdomain/zero/1.0/
# 33        321603  http://creativecommons.org/publicdomain/zero/1.0/
# 34        425909  http://creativecommons.org/publicdomain/zero/1.0/
# 35         63530  http://creativecommons.org/publicdomain/zero/1.0/
# 36        346580  http://creativecommons.org/publicdomain/zero/1.0/
# 37        169085  http://creativecommons.org/publicdomain/zero/1.0/
# 38        428377        http://creativecommons.org/licenses/by/3.0/
# 39         25310  http://creativecommons.org/publicdomain/zero/1.0/
# 40        377779  http://creativecommons.org/publicdomain/zero/1.0/
# 41        418730  http://creativecommons.org/publicdomain/zero/1.0/
# 42        228362  http://creativecommons.org/publicdomain/zero/1.0/
# 43        388042        http://creativecommons.org/licenses/by/3.0/
# 44        176434        http://creativecommons.org/licenses/by/3.0/
# 45        432874        http://creativecommons.org/licenses/by/3.0/
# 46        219605        http://creativecommons.org/licenses/by/3.0/
# 47         98936        http://creativecommons.org/licenses/by/3.0/
# 48         20717        http://creativecommons.org/licenses/by/3.0/
# 49        241132        http://creativecommons.org/licenses/by/3.0/
# 50        412157  http://creativecommons.org/publicdomain/zero/1.0/
# 51        434823  http://creativecommons.org/publicdomain/zero/1.0/
# 52        409614  http://creativecommons.org/publicdomain/zero/1.0/
# 53        449520  http://creativecommons.org/publicdomain/zero/1.0/
# 54        257769        http://creativecommons.org/licenses/by/3.0/
# 55         99636        http://creativecommons.org/licenses/by/3.0/
# 56         35035        http://creativecommons.org/licenses/by/3.0/
# 57        391100  http://creativecommons.org/publicdomain/zero/1.0/
# 58         24786  http://creativecommons.org/publicdomain/zero/1.0/
# 59        207952        http://creativecommons.org/licenses/by/3.0/
#
#                                          name  \
# 0          Snare Drum, Single Hit, A (H1).wav
# 1                                       Drums
# 2                               Drum R 12.wav
# 3                         SH01a Bass Drum 004
# 4                          m3mphiz_drum_1.wav
# 5                      Kick Drum (Lord Lokus)
# 6              120 Dertill n Amp Drums 01.wav
# 7                      Deep House Kick Drum 1
# 8                             Drum rolls1.wav
# 9                  Drum D'n'B FBB Line 02.aif
# 10                       FD808A Bass Drum.wav
# 11                             eardigi_drums_
# 12                    Electronic Kick Drum #2
# 13                   Electronic Snare Drum #1
# 14                                  Kick Drum
# 15                           bitcrushed_drums
# 16                                   edm kick
# 17                           let-it-go_break1
# 18         Junk Drum Kit: Hi Tom (Single Hit)
# 19                            Hand Drum 5.wav
# 20                135 Humandfood Drums 01.wav
# 21                Triton BassDrum Beat 2d.wav
# 22                                 drums8.wav
# 23                                    che.wav
# 24    D'n'B / breakbeat acoustic loop 157 BPM
# 25                        Linn Snare hard.WAV
# 26                           Snare drum 2.wav
# 27                            Mutant_KICK.wav
# 28      Bass drum (bdrum_special_sidehit.wav)
# 29                    short-ringmod-drums.wav
# 30                       Clap, Single, 12.wav
# 31                                  clap3.wav
# 32  1388_PERC_CLAPS im FreifeldPhilDav_04.wav
# 33                               ClapClap.wav
# 34                             hands clapping
# 35                                   clap.wav
# 36                                   clap.wav
# 37                                 Disco Clap
# 38                           17-Palmadas..wav
# 39                         Mini_Clap_ses1.wav
# 40                        Handclap-06-six.aif
# 41                             Synth Clap.wav
# 42                               Clapping.wav
# 43                                   Clap.wav
# 44              Pitch_down_tempo_up_claps.aif
# 45                           LFS_YayCheer.wav
# 46                    amy_stackedclaps_1b.wav
# 47                               Rock you.wav
# 48             small_applause-short_deepA.wav
# 49                       shortapplause_01.wav
# 50                              High Five.m4a
# 51                                   Applause
# 52                                    Palmada
# 53               High Five (with added audio)
# 54                       Crowd applause 2.wav
# 55             small crowd yelling 'YEAH'.wav
# 56                       20070516.goal.01.wav
# 57                              Testical Fart
# 58                               clap mix.wav
# 59                                    Claps 3
#
#                                         path  \
# 0   deliverables/drums/410514_5121236-hq.ogg
# 1   deliverables/drums/190613_3172867-hq.ogg
# 2   deliverables/drums/384668_5591103-hq.ogg
# 3   deliverables/drums/459895_4448255-hq.ogg
# 4   deliverables/drums/118524_1753199-hq.ogg
# 5   deliverables/drums/318330_1990402-hq.ogg
# 6    deliverables/drums/96016_1603602-hq.ogg
# 7   deliverables/drums/264285_1126957-hq.ogg
# 8    deliverables/drums/397016_994215-hq.ogg
# 9     deliverables/drums/324236_42810-hq.ogg
# 10  deliverables/drums/455633_3677139-hq.ogg
# 11  deliverables/drums/323261_5512320-hq.ogg
# 12  deliverables/drums/271078_4965320-hq.ogg
# 13  deliverables/drums/269719_4965320-hq.ogg
# 14  deliverables/drums/410149_7383104-hq.ogg
# 15  deliverables/drums/137779_1684206-hq.ogg
# 16  deliverables/drums/198100_3680406-hq.ogg
# 17  deliverables/drums/156020_2633010-hq.ogg
# 18  deliverables/drums/340467_5205523-hq.ogg
# 19  deliverables/drums/194021_3022224-hq.ogg
# 20  deliverables/drums/106144_1603602-hq.ogg
# 21  deliverables/drums/116615_1956076-hq.ogg
# 22  deliverables/drums/234425_2482480-hq.ogg
# 23  deliverables/drums/445068_7535020-hq.ogg
# 24  deliverables/drums/185615_1038806-hq.ogg
# 25     deliverables/drums/41355_27750-hq.ogg
# 26   deliverables/drums/82247_1299633-hq.ogg
# 27  deliverables/drums/414680_8162553-hq.ogg
# 28  deliverables/drums/375287_2475994-hq.ogg
# 29  deliverables/drums/100789_1562261-hq.ogg
# 30  deliverables/drums/404539_5121236-hq.ogg
# 31  deliverables/drums/436674_8904693-hq.ogg
# 32  deliverables/drums/351993_1934467-hq.ogg
# 33  deliverables/drums/321603_2331702-hq.ogg
# 34  deliverables/drums/425909_8563244-hq.ogg
# 35    deliverables/drums/63530_398161-hq.ogg
# 36  deliverables/drums/346580_4385633-hq.ogg
# 37  deliverables/drums/169085_2514850-hq.ogg
# 38  deliverables/drums/428377_7890063-hq.ogg
# 39    deliverables/drums/25310_173513-hq.ogg
# 40  deliverables/drums/377779_5832939-hq.ogg
# 41  deliverables/drums/418730_7844747-hq.ogg
# 42  deliverables/drums/228362_3370951-hq.ogg
# 43  deliverables/drums/388042_7282645-hq.ogg
# 44  deliverables/drums/176434_3262743-hq.ogg
# 45  deliverables/drums/432874_4157918-hq.ogg
# 46  deliverables/drums/219605_3008343-hq.ogg
# 47    deliverables/drums/98936_649468-hq.ogg
# 48    deliverables/drums/20717_104634-hq.ogg
# 49  deliverables/drums/241132_4157918-hq.ogg
# 50  deliverables/drums/412157_7985990-hq.ogg
# 51  deliverables/drums/434823_2927958-hq.ogg
# 52  deliverables/drums/409614_6446972-hq.ogg
# 53  deliverables/drums/449520_9289636-hq.ogg
# 54  deliverables/drums/257769_4157918-hq.ogg
# 55   deliverables/drums/99636_1163166-hq.ogg
# 56      deliverables/drums/35035_8043-hq.ogg
# 57  deliverables/drums/391100_7284820-hq.ogg
# 58    deliverables/drums/24786_165785-hq.ogg
# 59    deliverables/drums/207952_19852-hq.ogg
#
#                                                  tags           username
# 0   [snare, Snare, Drum, percussion, Drumstick, dr...         InspectorJ
# 1   [Drum, Hi-Hats, J-Lee, Hi, 4x4-Records, Drums,...             Goup_1
# 2                              [drums, tamil, Indian]           mathan24
# 3   [bassdrum, kick, bd, drums, percussion, bass-d...            ANARKYA
# 4                           [bass, drums, hard, kick]            M3MPHiZ
# 5                               [Sample, Drums, Kick]     Freakshitor669
# 6        [bit, crushed, digital, dirty, drums, synth]         gunnbladez
# 7   [Heavy, Electric-Dance-Music, Matt, Hit, Sub, ...            Mattc90
# 8   [sticks, roll, drumbreak, percussion-loop, aco...               Jedo
# 9   [Heavy, B, Drum, D, DnB, n, Break, Drums, Brea...             NEUTRi
# 10                  [drums, kick, drum, 808, machine]     Uberproduktion
# 11  [drum, drum-and-bass, amen, beat, dnb, break, ...            scale75
# 12  [Synthesizer, Music, Closed, Digital, Electro,...         IanStarGem
# 13  [Sample, Stereo, Noise, Drum, Bass, Punchy, Be...         IanStarGem
# 14  [bass, Kick, drum, drums, trap, music, future,...       ScreamStudio
# 15  [drum-loop, processing, drum, bitcrusher, nois...               skxr
# 16                    [kick, music, bass, drums, edm]           owowowwo
# 17  [drums, drum-and-bass, distortion, recording, ...  algorhythms_co_uk
# 18  [junk, drum, tom, kit, percussion, single, dru...           daehedon
# 19  [sound, drum, random, hand, percussion, percus...        potentjello
# 20  [drums, filter, free, guitar, gunnbladez, loop...         gunnbladez
# 21  [beat, distorted, drums, fuzzy, grunge, korg, ...             Puniho
# 22                          [beats, drum-loop, drums]           mitchelk
# 23    [organic, drums, percussive, Face, drum, sound]            aj13461
# 24  [dnb, beat, drumkit, fast, drums, breakbeat, a...               unfa
# 25                                            [drums]          elnaturel
# 26                      [drums, sd, snare, snaredrum]              KEVOY
# 27                           [kick, drums, bass-drum]       thunderbunny
# 28  [drums, percussion, drum, bass, vsco-2, single...            Samulis
# 29  [beats, drums, electronic, hit, loop, percussi...       illconceived
# 30  [Clap, clap, clapping, hand, Claps, Single, cl...         InspectorJ
# 31                            [hands, clap, clapping]        herraportti
# 32  [Handclap, no, clapping, hands, reflections, F...         davidmenke
# 33        [clopping, crocodile, clapping, clop, clap]   corentin_faucher
# 34                [hands, clapping, InterSpecies2018]         NatalieTre
# 35                      [clap, clapping, hand, hands]     florian_reinke
# 36                            [clapping, clap, hands]      EathanMarkson
# 37  [stereo, layered, clap, hands, multiple, clapp...         NenadSimic
# 38                            [hands, clapping, home]            sofi.om
# 39  [2006, action, audiencia, august, barcelona, c...          freesound
# 40  [groove, rhythm, music, clapping, beat, handclap]       meisterleise
# 41      [Hand, Clap, WavePad, Clapping, Drum-Machine]          Lynx_5969
# 42  [School, Field-Recording, People, Clapping, Pu...            18hiltc
# 43            [handclap, slap, hands, clap, clapping]     Sami_Kullström
# 44        [clapping, tempo, up, lowered, pitch, sped]          ajkerekes
# 45  [lo-fi, lo-fi-stupidity, cheer, cheering, hoor...            xtrgamr
# 46                        [claps, Clapping, handclap]          ani_music
# 47  [bang, banging, beat, clap, clapping, hand, ha...         juskiddink
# 48  [applause, clap, clapping, crowd, environmenta...            destron
# 49  [applause, crowd, clapping, accomplishment, ac...            xtrgamr
# 50  [clap, hands, five, high, hand, clapping, hand...     chancelombardo
# 51  [film, clap, sound-design, audience, crowd, cl...            bolkmar
# 52                     [hands, human, hand, clapping]            Pipe98x
# 53           [laughing, clapping, talking, high-five]           12572598
# 54  [applause, crowd, applaud, clapping, applaudin...            xtrgamr
# 55  [ambience, applaud, applauding, applause, appr...            Tomlija
# 56  [applause, bravo, cheer, clapping, encouragement]           dobroide
# 57  [man, testical, human, balls, fart, clapping, ...          efinpeter
# 58                                             [clap]        young_daddy
# 59  [softsynth, pro, abl, percussion, tb-303, drum...           altemark
#     freesound_id                                            license  \
# 0         410514        http://creativecommons.org/licenses/by/3.0/
# 1         190613        http://creativecommons.org/licenses/by/3.0/
# 2         384668  http://creativecommons.org/publicdomain/zero/1.0/
# 3         459895  http://creativecommons.org/publicdomain/zero/1.0/
# 4         118524  http://creativecommons.org/publicdomain/zero/1.0/
# 5         318330        http://creativecommons.org/licenses/by/3.0/
# 6          96016        http://creativecommons.org/licenses/by/3.0/
# 7         264285  http://creativecommons.org/publicdomain/zero/1.0/
# 8         397016        http://creativecommons.org/licenses/by/3.0/
# 9         324236        http://creativecommons.org/licenses/by/3.0/
# 10        455633  http://creativecommons.org/publicdomain/zero/1.0/
# 11        323261        http://creativecommons.org/licenses/by/3.0/
# 12        271078  http://creativecommons.org/publicdomain/zero/1.0/
# 13        269719  http://creativecommons.org/publicdomain/zero/1.0/
# 14        410149  http://creativecommons.org/publicdomain/zero/1.0/
# 15        137779        http://creativecommons.org/licenses/by/3.0/
# 16        198100        http://creativecommons.org/licenses/by/3.0/
# 17        156020        http://creativecommons.org/licenses/by/3.0/
# 18        340467  http://creativecommons.org/publicdomain/zero/1.0/
# 19        194021  http://creativecommons.org/publicdomain/zero/1.0/
# 20        106144        http://creativecommons.org/licenses/by/3.0/
# 21        116615        http://creativecommons.org/licenses/by/3.0/
# 22        234425        http://creativecommons.org/licenses/by/3.0/
# 23        445068  http://creativecommons.org/publicdomain/zero/1.0/
# 24        185615        http://creativecommons.org/licenses/by/3.0/
# 25         41355  http://creativecommons.org/publicdomain/zero/1.0/
# 26         82247  http://creativecommons.org/publicdomain/zero/1.0/
# 27        414680        http://creativecommons.org/licenses/by/3.0/
# 28        375287  http://creativecommons.org/publicdomain/zero/1.0/
# 29        100789        http://creativecommons.org/licenses/by/3.0/
# 30        404539        http://creativecommons.org/licenses/by/3.0/
# 31        436674  http://creativecommons.org/publicdomain/zero/1.0/
# 32        351993  http://creativecommons.org/publicdomain/zero/1.0/
# 33        321603  http://creativecommons.org/publicdomain/zero/1.0/
# 34        425909  http://creativecommons.org/publicdomain/zero/1.0/
# 35         63530  http://creativecommons.org/publicdomain/zero/1.0/
# 36        346580  http://creativecommons.org/publicdomain/zero/1.0/
# 37        169085  http://creativecommons.org/publicdomain/zero/1.0/
# 38        428377        http://creativecommons.org/licenses/by/3.0/
# 39         25310  http://creativecommons.org/publicdomain/zero/1.0/
# 40        377779  http://creativecommons.org/publicdomain/zero/1.0/
# 41        418730  http://creativecommons.org/publicdomain/zero/1.0/
# 42        228362  http://creativecommons.org/publicdomain/zero/1.0/
# 43        388042        http://creativecommons.org/licenses/by/3.0/
# 44        176434        http://creativecommons.org/licenses/by/3.0/
# 45        432874        http://creativecommons.org/licenses/by/3.0/
# 46        219605        http://creativecommons.org/licenses/by/3.0/
# 47         98936        http://creativecommons.org/licenses/by/3.0/
# 48         20717        http://creativecommons.org/licenses/by/3.0/
# 49        241132        http://creativecommons.org/licenses/by/3.0/
# 50        412157  http://creativecommons.org/publicdomain/zero/1.0/
# 51        434823  http://creativecommons.org/publicdomain/zero/1.0/
# 52        409614  http://creativecommons.org/publicdomain/zero/1.0/
# 53        449520  http://creativecommons.org/publicdomain/zero/1.0/
# 54        257769        http://creativecommons.org/licenses/by/3.0/
# 55         99636        http://creativecommons.org/licenses/by/3.0/
# 56         35035        http://creativecommons.org/licenses/by/3.0/
# 57        391100  http://creativecommons.org/publicdomain/zero/1.0/
# 58         24786  http://creativecommons.org/publicdomain/zero/1.0/
# 59        207952        http://creativecommons.org/licenses/by/3.0/
#
#                                          name  \
# 0          Snare Drum, Single Hit, A (H1).wav
# 1                                       Drums
# 2                               Drum R 12.wav
# 3                         SH01a Bass Drum 004
# 4                          m3mphiz_drum_1.wav
# 5                      Kick Drum (Lord Lokus)
# 6              120 Dertill n Amp Drums 01.wav
# 7                      Deep House Kick Drum 1
# 8                             Drum rolls1.wav
# 9                  Drum D'n'B FBB Line 02.aif
# 10                       FD808A Bass Drum.wav
# 11                             eardigi_drums_
# 12                    Electronic Kick Drum #2
# 13                   Electronic Snare Drum #1
# 14                                  Kick Drum
# 15                           bitcrushed_drums
# 16                                   edm kick
# 17                           let-it-go_break1
# 18         Junk Drum Kit: Hi Tom (Single Hit)
# 19                            Hand Drum 5.wav
# 20                135 Humandfood Drums 01.wav
# 21                Triton BassDrum Beat 2d.wav
# 22                                 drums8.wav
# 23                                    che.wav
# 24    D'n'B / breakbeat acoustic loop 157 BPM
# 25                        Linn Snare hard.WAV
# 26                           Snare drum 2.wav
# 27                            Mutant_KICK.wav
# 28      Bass drum (bdrum_special_sidehit.wav)
# 29                    short-ringmod-drums.wav
# 30                       Clap, Single, 12.wav
# 31                                  clap3.wav
# 32  1388_PERC_CLAPS im FreifeldPhilDav_04.wav
# 33                               ClapClap.wav
# 34                             hands clapping
# 35                                   clap.wav
# 36                                   clap.wav
# 37                                 Disco Clap
# 38                           17-Palmadas..wav
# 39                         Mini_Clap_ses1.wav
# 40                        Handclap-06-six.aif
# 41                             Synth Clap.wav
# 42                               Clapping.wav
# 43                                   Clap.wav
# 44              Pitch_down_tempo_up_claps.aif
# 45                           LFS_YayCheer.wav
# 46                    amy_stackedclaps_1b.wav
# 47                               Rock you.wav
# 48             small_applause-short_deepA.wav
# 49                       shortapplause_01.wav
# 50                              High Five.m4a
# 51                                   Applause
# 52                                    Palmada
# 53               High Five (with added audio)
# 54                       Crowd applause 2.wav
# 55             small crowd yelling 'YEAH'.wav
# 56                       20070516.goal.01.wav
# 57                              Testical Fart
# 58                               clap mix.wav
# 59                                    Claps 3
#
#                                         path  \
# 0   deliverables/drums/410514_5121236-hq.ogg
# 1   deliverables/drums/190613_3172867-hq.ogg
# 2   deliverables/drums/384668_5591103-hq.ogg
# 3   deliverables/drums/459895_4448255-hq.ogg
# 4   deliverables/drums/118524_1753199-hq.ogg
# 5   deliverables/drums/318330_1990402-hq.ogg
# 6    deliverables/drums/96016_1603602-hq.ogg
# 7   deliverables/drums/264285_1126957-hq.ogg
# 8    deliverables/drums/397016_994215-hq.ogg
# 9     deliverables/drums/324236_42810-hq.ogg
# 10  deliverables/drums/455633_3677139-hq.ogg
# 11  deliverables/drums/323261_5512320-hq.ogg
# 12  deliverables/drums/271078_4965320-hq.ogg
# 13  deliverables/drums/269719_4965320-hq.ogg
# 14  deliverables/drums/410149_7383104-hq.ogg
# 15  deliverables/drums/137779_1684206-hq.ogg
# 16  deliverables/drums/198100_3680406-hq.ogg
# 17  deliverables/drums/156020_2633010-hq.ogg
# 18  deliverables/drums/340467_5205523-hq.ogg
# 19  deliverables/drums/194021_3022224-hq.ogg
# 20  deliverables/drums/106144_1603602-hq.ogg
# 21  deliverables/drums/116615_1956076-hq.ogg
# 22  deliverables/drums/234425_2482480-hq.ogg
# 23  deliverables/drums/445068_7535020-hq.ogg
# 24  deliverables/drums/185615_1038806-hq.ogg
# 25     deliverables/drums/41355_27750-hq.ogg
# 26   deliverables/drums/82247_1299633-hq.ogg
# 27  deliverables/drums/414680_8162553-hq.ogg
# 28  deliverables/drums/375287_2475994-hq.ogg
# 29  deliverables/drums/100789_1562261-hq.ogg
# 30  deliverables/drums/404539_5121236-hq.ogg
# 31  deliverables/drums/436674_8904693-hq.ogg
# 32  deliverables/drums/351993_1934467-hq.ogg
# 33  deliverables/drums/321603_2331702-hq.ogg
# 34  deliverables/drums/425909_8563244-hq.ogg
# 35    deliverables/drums/63530_398161-hq.ogg
# 36  deliverables/drums/346580_4385633-hq.ogg
# 37  deliverables/drums/169085_2514850-hq.ogg
# 38  deliverables/drums/428377_7890063-hq.ogg
# 39    deliverables/drums/25310_173513-hq.ogg
# 40  deliverables/drums/377779_5832939-hq.ogg
# 41  deliverables/drums/418730_7844747-hq.ogg
# 42  deliverables/drums/228362_3370951-hq.ogg
# 43  deliverables/drums/388042_7282645-hq.ogg
# 44  deliverables/drums/176434_3262743-hq.ogg
# 45  deliverables/drums/432874_4157918-hq.ogg
# 46  deliverables/drums/219605_3008343-hq.ogg
# 47    deliverables/drums/98936_649468-hq.ogg
# 48    deliverables/drums/20717_104634-hq.ogg
# 49  deliverables/drums/241132_4157918-hq.ogg
# 50  deliverables/drums/412157_7985990-hq.ogg
# 51  deliverables/drums/434823_2927958-hq.ogg
# 52  deliverables/drums/409614_6446972-hq.ogg
# 53  deliverables/drums/449520_9289636-hq.ogg
# 54  deliverables/drums/257769_4157918-hq.ogg
# 55   deliverables/drums/99636_1163166-hq.ogg
# 56      deliverables/drums/35035_8043-hq.ogg
# 57  deliverables/drums/391100_7284820-hq.ogg
# 58    deliverables/drums/24786_165785-hq.ogg
# 59    deliverables/drums/207952_19852-hq.ogg
#
#                                                  tags           username
# 0   [snare, Snare, Drum, percussion, Drumstick, dr...         InspectorJ
# 1   [Drum, Hi-Hats, J-Lee, Hi, 4x4-Records, Drums,...             Goup_1
# 2                              [drums, tamil, Indian]           mathan24
# 3   [bassdrum, kick, bd, drums, percussion, bass-d...            ANARKYA
# 4                           [bass, drums, hard, kick]            M3MPHiZ
# 5                               [Sample, Drums, Kick]     Freakshitor669
# 6        [bit, crushed, digital, dirty, drums, synth]         gunnbladez
# 7   [Heavy, Electric-Dance-Music, Matt, Hit, Sub, ...            Mattc90
# 8   [sticks, roll, drumbreak, percussion-loop, aco...               Jedo
# 9   [Heavy, B, Drum, D, DnB, n, Break, Drums, Brea...             NEUTRi
# 10                  [drums, kick, drum, 808, machine]     Uberproduktion
# 11  [drum, drum-and-bass, amen, beat, dnb, break, ...            scale75
# 12  [Synthesizer, Music, Closed, Digital, Electro,...         IanStarGem
# 13  [Sample, Stereo, Noise, Drum, Bass, Punchy, Be...         IanStarGem
# 14  [bass, Kick, drum, drums, trap, music, future,...       ScreamStudio
# 15  [drum-loop, processing, drum, bitcrusher, nois...               skxr
# 16                    [kick, music, bass, drums, edm]           owowowwo
# 17  [drums, drum-and-bass, distortion, recording, ...  algorhythms_co_uk
# 18  [junk, drum, tom, kit, percussion, single, dru...           daehedon
# 19  [sound, drum, random, hand, percussion, percus...        potentjello
# 20  [drums, filter, free, guitar, gunnbladez, loop...         gunnbladez
# 21  [beat, distorted, drums, fuzzy, grunge, korg, ...             Puniho
# 22                          [beats, drum-loop, drums]           mitchelk
# 23    [organic, drums, percussive, Face, drum, sound]            aj13461
# 24  [dnb, beat, drumkit, fast, drums, breakbeat, a...               unfa
# 25                                            [drums]          elnaturel
# 26                      [drums, sd, snare, snaredrum]              KEVOY
# 27                           [kick, drums, bass-drum]       thunderbunny
# 28  [drums, percussion, drum, bass, vsco-2, single...            Samulis
# 29  [beats, drums, electronic, hit, loop, percussi...       illconceived
# 30  [Clap, clap, clapping, hand, Claps, Single, cl...         InspectorJ
# 31                            [hands, clap, clapping]        herraportti
# 32  [Handclap, no, clapping, hands, reflections, F...         davidmenke
# 33        [clopping, crocodile, clapping, clop, clap]   corentin_faucher
# 34                [hands, clapping, InterSpecies2018]         NatalieTre
# 35                      [clap, clapping, hand, hands]     florian_reinke
# 36                            [clapping, clap, hands]      EathanMarkson
# 37  [stereo, layered, clap, hands, multiple, clapp...         NenadSimic
# 38                            [hands, clapping, home]            sofi.om
# 39  [2006, action, audiencia, august, barcelona, c...          freesound
# 40  [groove, rhythm, music, clapping, beat, handclap]       meisterleise
# 41      [Hand, Clap, WavePad, Clapping, Drum-Machine]          Lynx_5969
# 42  [School, Field-Recording, People, Clapping, Pu...            18hiltc
# 43            [handclap, slap, hands, clap, clapping]     Sami_Kullström
# 44        [clapping, tempo, up, lowered, pitch, sped]          ajkerekes
# 45  [lo-fi, lo-fi-stupidity, cheer, cheering, hoor...            xtrgamr
# 46                        [claps, Clapping, handclap]          ani_music
# 47  [bang, banging, beat, clap, clapping, hand, ha...         juskiddink
# 48  [applause, clap, clapping, crowd, environmenta...            destron
# 49  [applause, crowd, clapping, accomplishment, ac...            xtrgamr
# 50  [clap, hands, five, high, hand, clapping, hand...     chancelombardo
# 51  [film, clap, sound-design, audience, crowd, cl...            bolkmar
# 52                     [hands, human, hand, clapping]            Pipe98x
# 53           [laughing, clapping, talking, high-five]           12572598
# 54  [applause, crowd, applaud, clapping, applaudin...            xtrgamr
# 55  [ambience, applaud, applauding, applause, appr...            Tomlija
# 56  [applause, bravo, cheer, clapping, encouragement]           dobroide
# 57  [man, testical, human, balls, fart, clapping, ...          efinpeter
# 58                                             [clap]        young_daddy
# 59  [softsynth, pro, abl, percussion, tb-303, drum...           altemark

# %%
# Out:
# (60, 6)
